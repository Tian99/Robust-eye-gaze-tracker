# %% [markdown]
# <h1><center>Report 10</center></h1>
# <h3><center>Jiachen Tian</center><h3>

# %% [markdown]
# # Introduction
# Optimization is almost done. The algorithm can now precisely detect and track position of the pupil and plot the result(x, y, r, blinking) based on frame numbers as illustrated below.

# %% [markdown]
# # Setup
# Setup path to include our files. import them. use `autoreload` to get changes in as they are made.

# %%
import os
import sys
import cv2
from matplotlib import pyplot as plt

# load our code
sys.path.insert(0, os.path.abspath('../'))
from plotting import auto_draw
# specific to jupyter notebook
from jupyter_help import cvplt, cvplt_sub
#Import image processing function from optimization
# load any changes as we make them
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Demo 1
# x, y, r blink plotting on one video file(1) at 4000 frames

# %%
#Video file used
image = cv2.imread("../input/chosen_pic.png")
cvplt(image)

# %%
ad = auto_draw()
#Read in the data that's run locally
data = ad.read('../data_output/pupil.csv')
#Draw the data
ad.draw_x(True)
ad.draw_y(True)
ad.draw_r(True)
ad.draw_blink(True)

# %% [markdown]
# x, y, r blink plotting on one video file for 10000 frames

# %%
ad = auto_draw()
#Read in the data that's run locally
data = ad.read('../data_output/pupil.csv')
#Draw the data
ad.draw_x(True)
ad.draw_y(True)
ad.draw_r(True)
ad.draw_blink(True)

# %% [markdown]
# # Demo 2
# x, y, r blink plotting on one video file(2) at 4000 frame

# %%
#Video file used
image = cv2.imread("../input/chosen_pic.png")
cvplt(image)

# %%
x, y, r blink plotting on one video file for 4000 frames

# %%
ad = auto_draw()
#Read in the data that's run locally
data = ad.read('../data_output/pupil.csv')
#Draw the data
ad.draw_x(True)
ad.draw_y(True)
ad.draw_r(True)
ad.draw_blink(True)

# %%
x, y, r blink plotting on one video file for 10000 frames

# %%
ad = auto_draw()
#Read in the data that's run locally
data = ad.read('../data_output/pupil.csv')
#Draw the data
ad.draw_x(True)
ad.draw_y(True)
ad.draw_r(True)
ad.draw_blink(True)

# %% [markdown]
# # Analysis
# As shown by the graphs plotted, the algorithm is able to detect and to plot eye pupil position, radius, and blink in a relatively precise way. However, noises are still present(Mostly caused by blinks and could be filtered out). Some data shown above, especially for demo 2, is hardly distinguishable by looking. Which would later by analyzed using statistics. Further optimization could be donw based upon correlation between KCF and Hough Transform.

# %% [markdown]
# # Conclusion
# Tracking optimization is almost done. Tasks remain include glint detection, pupil&glint matching and program runtime optimization.
