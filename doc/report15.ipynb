# %% [markdown]
# <h1><center>Report 15</center></h1>
# <h3><center>Jiachen Tian</center><h3>

# %% [markdown]
# # Introduction
# The eye-tracking algorithm is about to be done. I can still pull off more filters and preprocessing steps to make it more precise, but that's gonna be after the data analysis. For data analysis, python will be used to rationalize all the data generated from the computer vision algorithm, but I will use R to train the machine learning algorithms(KNN, random forest, boosted forest, SVM, Linear regression, logistic regression, etc). Since the original files provided have very limited data, python would be used to generate a thorough collection of data that can be used to train all the modules aforementioned, and the best performing module would be selected for data analysis. In ideal outcomes, the results would get better and better the more you use this tracker(Ability to self evolve using machine learning algorithms).

# %% [markdown]
# # Tasks
# 1. Get the five states of staring.
# 2. Map the trakced data to the original coordinates(Done after successful identificaitons of the five states).

# %% [markdown]
# # Issues
# From what I've observed, there is a huge gap in time between the ideal data and the data extracted by the tracker. As shown below, the plot is colored based upon the files from the MRI machine. The correct sequence would be cue -> vgs -> dly -> mgs -> iti as marked in the image. However, At the very first section of the trail, at the green color section where the data would increase, but it lagged. The potential reason that causes the lag might be because the time marked in the machine might not be the time it starts recording videos.

# %% [markdown]
# ![filtered_x_pupil.png](attachment:filtered_x_pupil.png)

# %% [markdown]
# # Solution
# even if the time in the original file is unreliable, we could still utilize the gap time between each state(For which we assume consistency with the pupil tracking data). Moreover, for all the states, 'cue' should be always constant. Therefore, if we could iterate all the 'cues' and find the smallest standard deviation of each 'cue' chunk, we could find the lagging time and adjust the original file accordingly and sync it with the tracked data.

# %% [markdown]
# # Conclusion
# This is going to be the last weely report. The final completed version of the tracker and the final report would be uploaded no later than Wednesday next week.
